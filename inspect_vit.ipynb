# %%
import importlib
import vit
importlib.reload(vit)
from vit import ViTForClassfication
model = ViTForClassfication(hidden_size=128, num_layers=3, num_heads=4)

from utils import visualize_images
visualize_images()
# Out:
# Files already downloaded and verified
